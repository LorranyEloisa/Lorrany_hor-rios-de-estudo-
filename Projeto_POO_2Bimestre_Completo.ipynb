# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
#testevalidação 20-05 teste atualizaçãpo fabio
class Estudo:
    def __init__(self, disciplina, dia, hora):
        """Método construtor inicializando os atributos"""
        self.disciplina = disciplina
        self.dia = dia
        self.hora = hora

    def exibir_dados(self):
        """Método para exibir os dados do estudo"""
        print(f"Disciplina: {self.disciplina}")
        print(f"Dia: {self.dia}")
        print(f"Hora: {self.hora}")
        print("-" * 30)

estudo1 = Estudo("Matemática", "segunda", "14:00")
estudo2 = Estudo("História", "quarta", "16:30")

estudo1.exibir_dados()
estudo2.exibir_dados()
# Out:
# Disciplina: Matemática
# Dia: segunda
# Hora: 14:00
# ------------------------------
# Disciplina: História
# Dia: quarta
# Hora: 16:30
# ------------------------------

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class Estudo:
    def __init__(self, disciplina, dia, hora):
        self.disciplina = disciplina
        self.dia = dia
        self.hora = hora

    def exibir_dados(self):
        print(f"Disciplina: {self.disciplina}")
        print(f"Dia: {self.dia}")
        print(f"Hora: {self.hora}")
        print("-" * 30)

    def mudar_hora(self, nova_hora):
        """Altera o horário do estudo"""
        self.hora = nova_hora
        print(f"A hora do estudo de {self.disciplina} foi alterada para {self.hora}")

    def mudar_dia(self, novo_dia):
        """Altera o dia do estudo"""
        self.dia = novo_dia
        print(f"O estudo de {self.disciplina} foi movido para {self.dia}")


class EstudoAvancado(Estudo):
    def __init__(self, disciplina, dia, hora, nivel):
        """Construtor da subclasse utilizando super()"""
        super().__init__(disciplina, dia, hora)
        self.nivel = nivel 
    def exibir_nivel(self):
        """Exibe o nível de estudo"""
        print(f"Nível de estudo: {self.nivel}")

    def mudar_nivel(self, novo_nivel):
        """Altera o nível de estudo"""
        self.nivel = novo_nivel
        print(f"O nível de estudo foi alterado para: {self.nivel}")


estudo1 = Estudo("Matemática", "segunda", "14:00")
estudo2 = Estudo("História", "quarta", "16:30")
estudo_avancado1 = EstudoAvancado("Física", "sexta", "10:00", "Avançado")

estudo1.exibir_dados()
estudo2.exibir_dados()

estudo1.mudar_hora("15:00")
estudo2.mudar_dia("sexta")
estudo1.exibir_dados()
estudo2.exibir_dados()

estudo_avancado1.exibir_dados()
estudo_avancado1.exibir_nivel()
estudo_avancado1.mudar_nivel("Intermediário")
estudo_avancado1.exibir_nivel()
# Out:
# Disciplina: Matemática
# Dia: segunda
# Hora: 14:00
# ------------------------------
# Disciplina: História
# Dia: quarta
# Hora: 16:30
# ------------------------------
# A hora do estudo de Matemática foi alterada para 15:00
# O estudo de História foi movido para sexta
# Disciplina: Matemática
# Dia: segunda
# Hora: 15:00
# ------------------------------
# Disciplina: História
# Dia: sexta
# Hora: 16:30
# ------------------------------
# Disciplina: Física
# Dia: sexta
# Hora: 10:00
# ------------------------------
# Nível de estudo: Avançado
# O nível de estudo foi alterado para: Intermediário
# Nível de estudo: Intermediário

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class Estudo:
    def __init__(self, disciplina, dia, hora):
        self.disciplina = disciplina
        self.dia = dia
        self.__hora = hora  

    def exibir_dados(self):
        print(f"Disciplina: {self.disciplina}")
        print(f"Dia: {self.dia}")
        print(f"Hora: {self.__hora}")
        print("-" * 30)

    
    def get_hora(self):
        return self.__hora

   
    def set_hora(self, nova_hora):
        if self.validar_hora(nova_hora):
            self.__hora = nova_hora
            print(f"A hora foi alterada para {self.__hora}")
        else:
            print("Hora inválida. Hora não alterada.")


    def validar_hora(self, hora):
    
        try:
            h, m = map(int, hora.split(":"))
            return 0 <= h < 24 and 0 <= m < 60
        except ValueError:
            return False


estudo1 = Estudo("Matemática", "segunda", "14:00")
estudo1.exibir_dados()

estudo1.set_hora("16:30")
estudo1.exibir_dados()

estudo1.set_hora("25:00")
# Out:
# Disciplina: Matemática
# Dia: segunda
# Hora: 14:00
# ------------------------------
# A hora foi alterada para 16:30
# Disciplina: Matemática
# Dia: segunda
# Hora: 16:30
# ------------------------------
# Hora inválida. Hora não alterada.

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3

class Estudo:
    def __init__(self, disciplina, dia, hora):
        self.disciplina = disciplina
        self.dia = dia
        self.__hora = hora

    def exibir_dados(self):
        print(f"Disciplina: {self.disciplina}")
        print(f"Dia: {self.dia}")
        print(f"Hora: {self.__hora}")
        print("-" * 30)

    def set_hora(self, nova_hora):
        if self.validar_hora(nova_hora):
            self.__hora = nova_hora
            print(f"A hora foi alterada para {self.__hora}")
        else:
            print("Hora inválida. Hora não alterada.")

    def validar_hora(self, hora):
        try:
            h, m = map(int, hora.split(":"))
            return 0 <= h < 24 and 0 <= m < 60
        except ValueError:
            return False

class EstudoAvancado(Estudo):
    def exibir_dados(self):
        print(f"Disciplina (Avançado): {self.disciplina}")
        print(f"Dia (Avançado): {self.dia}")
        print(f"Hora (Avançado): {self._Estudo__hora}")
        print("-" * 30)

conn = sqlite3.connect('agenda_estudos.db')
cursor = conn.cursor()

cursor.execute('''
CREATE TABLE IF NOT EXISTS estudos (
    id INTEGER PRIMARY KEY,
    disciplina TEXT,
    dia TEXT,
    hora TEXT
)
''')


def inserir_estudo(disciplina, dia, hora):
    cursor.execute('''
    INSERT INTO estudos (disciplina, dia, hora)
    VALUES (?, ?, ?)
    ''', (disciplina, dia, hora))
    conn.commit()

def consultar_estudos():
    cursor.execute('SELECT * FROM estudos')
    return cursor.fetchall()

def excluir_estudo(estudo_id):
    cursor.execute('DELETE FROM estudos WHERE id = ?', (estudo_id,))
    conn.commit()

inserir_estudo("Matemática", "segunda", "14:00")
inserir_estudo("História", "quarta", "16:30")

estudos = consultar_estudos()
for estudo in estudos:
    print(estudo)

excluir_estudo(1)

conn.close()
# Out:
# (1, 'Matemática', 'segunda', '14:00')
# (2, 'História', 'quarta', '16:30')

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Importando o módulo sqlite3 para integração com o banco de dados SQLite
import sqlite3

# -----------------------------------------------
# PARTE 1 - Classe Principal e Objetos
# -----------------------------------------------

class Estudo:
    def __init__(self, disciplina, dia, hora):
        """
        Método construtor que inicializa os atributos de cada objeto.
        :param disciplina: Nome da disciplina de estudo.
        :param dia: Dia da semana em que o estudo ocorre.
        :param hora: Hora em que o estudo é programado.
        """
        self.disciplina = disciplina
        self.dia = dia
        self.__hora = hora  # Atributo privado: hora do estudo.

    def exibir_dados(self):
        """Exibe os dados do estudo formatados."""
        print(f"Disciplina: {self.disciplina}")
        print(f"Dia: {self.dia}")
        print(f"Hora: {self.__hora}")
        print("-" * 30)

    def set_hora(self, nova_hora):
        """
        Método set para alterar a hora de estudo, com validação de formato.
        :param nova_hora: A nova hora a ser atribuída ao atributo __hora.
        """
        if self.validar_hora(nova_hora):
            self.__hora = nova_hora
            print(f"A hora foi alterada para {self.__hora}")
        else:
            print("Hora inválida. Hora não alterada.")

    def validar_hora(self, hora):
        """
        Valida se a hora está no formato correto (HH:MM).
        :param hora: Hora a ser validada.
        :return: True se for válida, False caso contrário.
        """
        try:
            h, m = map(int, hora.split(":"))
            return 0 <= h < 24 and 0 <= m < 60
        except ValueError:
            return False


# -----------------------------------------------
# PARTE 2 - Métodos e Herança
# -----------------------------------------------

class EstudoAvancado(Estudo):
    def __init__(self, disciplina, dia, hora, nivel):
        """
        Método construtor da subclasse EstudoAvancado.
        :param disciplina: Nome da disciplina de estudo.
        :param dia: Dia da semana.
        :param hora: Hora do estudo.
        :param nivel: Nível de dificuldade do estudo (ex: básico, intermediário, avançado).
        """
        super().__init__(disciplina, dia, hora)
        self.nivel = nivel  # Atributo exclusivo da subclasse EstudoAvancado.

    def exibir_dados(self):
        """Sobrescreve o método exibir_dados para incluir o nível de estudo."""
        print(f"Disciplina (Avançado): {self.disciplina}")
        print(f"Dia (Avançado): {self.dia}")
        print(f"Hora (Avançado): {self._Estudo__hora}")
        print(f"Nível de Estudo: {self.nivel}")
        print("-" * 30)

    def mudar_nivel(self, novo_nivel):
        """Método exclusivo para alterar o nível de estudo."""
        self.nivel = novo_nivel
        print(f"O nível de estudo foi alterado para: {self.nivel}")


# -----------------------------------------------
# PARTE 3 - Encapsulamento e Abstração
# -----------------------------------------------

# Aqui, o atributo __hora foi tornado privado na classe Estudo
# Métodos get/set são criados para interagir com o atributo privado.

# -----------------------------------------------
# PARTE 4 - Polimorfismo e Banco de Dados
# -----------------------------------------------

# Funções de banco de dados

def criar_conexao_db():
    """Cria e retorna uma conexão com o banco de dados SQLite."""
    conn = sqlite3.connect('agenda_estudos.db')
    return conn

def criar_tabela(conn):
    """Cria a tabela de estudos no banco de dados."""
    cursor = conn.cursor()
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS estudos (
        id INTEGER PRIMARY KEY,
        disciplina TEXT,
        dia TEXT,
        hora TEXT
    )
    ''')
    conn.commit()

def inserir_estudo(conn, disciplina, dia, hora):
    """Insere um novo registro de estudo na tabela."""
    cursor = conn.cursor()
    cursor.execute('''
    INSERT INTO estudos (disciplina, dia, hora)
    VALUES (?, ?, ?)
    ''', (disciplina, dia, hora))
    conn.commit()

def consultar_estudos(conn):
    """Consulta todos os registros de estudos no banco de dados."""
    cursor = conn.cursor()
    cursor.execute('SELECT * FROM estudos')
    return cursor.fetchall()

def excluir_estudo(conn, estudo_id):
    """Exclui um registro de estudo pela ID."""
    cursor = conn.cursor()
    cursor.execute('DELETE FROM estudos WHERE id = ?', (estudo_id,))
    conn.commit()


# -----------------------------------------------
# PARTE 5 - Projeto Final e Organização
# -----------------------------------------------

def main():
    # Criando objetos da classe Estudo
    estudo1 = Estudo("Matemática", "segunda", "14:00")
    estudo2 = Estudo("História", "quarta", "16:30")

    # Exibindo dados dos estudos
    estudo1.exibir_dados()
    estudo2.exibir_dados()

    # Alterando hora e dia dos estudos
    estudo1.set_hora("15:00")
    estudo2.set_hora("17:00")
    estudo1.set_hora("25:00")  # Tentando hora inválida

    # Criando um objeto da subclasse EstudoAvancado
    estudo_avancado1 = EstudoAvancado("Física", "sexta", "10:00", "Avançado")
    estudo_avancado1.exibir_dados()

    # Alterando o nível de estudo na subclasse
    estudo_avancado1.mudar_nivel("Intermediário")
    estudo_avancado1.exibir_dados()

    # Integração com banco de dados
    conn = criar_conexao_db()
    criar_tabela(conn)

    # Inserindo estudos no banco de dados
    inserir_estudo(conn, "Matemática", "segunda", "14:00")
    inserir_estudo(conn, "História", "quarta", "16:30")

    # Consultando todos os registros de estudo
    estudos = consultar_estudos(conn)
    print("Estudos no banco de dados:")
    for estudo in estudos:
        print(estudo)

    # Excluindo um estudo pelo ID
    excluir_estudo(conn, 1)

    # Consultando novamente após exclusão
    estudos = consultar_estudos(conn)
    print("Estudos após exclusão:")
    for estudo in estudos:
        print(estudo)

    # Fechando a conexão com o banco de dados
    conn.close()

if __name__ == "__main__":
    main()
# Out:
# Disciplina: Matemática
# Dia: segunda
# Hora: 14:00
# ------------------------------
# Disciplina: História
# Dia: quarta
# Hora: 16:30
# ------------------------------
# A hora foi alterada para 15:00
# A hora foi alterada para 17:00
# Hora inválida. Hora não alterada.
# Disciplina (Avançado): Física
# Dia (Avançado): sexta
# Hora (Avançado): 10:00
# Nível de Estudo: Avançado
# ------------------------------
# O nível de estudo foi alterado para: Intermediário
# Disciplina (Avançado): Física
# Dia (Avançado): sexta
# Hora (Avançado): 10:00
# Nível de Estudo: Intermediário
# ------------------------------
# Estudos no banco de dados:
# (2, 'História', 'quarta', '16:30')
# (3, 'Matemática', 'segunda', '14:00')
# (4, 'História', 'quarta', '16:30')
# Estudos após exclusão:
# (2, 'História', 'quarta', '16:30')
# (3, 'Matemática', 'segunda', '14:00')
# (4, 'História', 'quarta', '16:30')
